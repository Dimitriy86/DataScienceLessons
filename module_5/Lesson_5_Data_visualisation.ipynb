# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
date = pd.date_range(start='2021-09-01', freq='D', periods=8)
plt.plot(date, [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature')
plt.title("Денна погода у м.Полтава", fontsize=15)
plt.xlabel('Дата', fontsize='small', color='midnightblue')
plt.ylabel('Температура', fontsize='small', color='midnightblue')
plt.text(date[0], 15, 'Осінь досіть тепла', color='blue')
plt.legend()
plt.show()

# %% [markdown]
# Компонування графіків

# %%
date = pd.date_range(start='2021-09-01', freq='D', periods=8)
fig, axs = plt.subplots()
axs.plot(date, [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature')
axs.plot(date, [19, 11, 16, 11, 10, 10, 11, 16], label='night temperature')
plt.ylabel('Дата', fontsize='small', color='midnightblue')
plt.ylabel('Температура', fontsize='small', color='midnightblue')
plt.title('Температура у м.Полтава', fontsize=15)
plt.text(date[0], 15, 'Осінь досить тепла', color='blue')
plt.legend()
plt.show()

# %% [markdown]
# Розділення графіків

# %%
date = pd.date_range(start='2021-09-01', freq='D', periods=8)
fig, axs = plt.subplots(2, 1)

axs[0].plot(date, [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature')
axs[1].plot(date, [19, 11, 16, 11, 10, 10, 11, 16], label='night temperature')

axs[0].set_title('Денна', fontsize=10)
axs[1].set_title('Нічна', fontsize=10)

fig.suptitle('Температура в м.Полтава', fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

date = pd.date_range(start="2021-09-01", freq="D", periods=8)
plt.plot(
    date,
    [23, 17, 17, 16, 15, 14, 17, 20],
    label="day temperature",
    linestyle="--",
    color="#FF5733",
)
plt.plot(
    date,
    [19, 11, 16, 11, 10, 10, 11, 16],
    label="night temperature",
    linestyle=":",
    color="#061358",
)
plt.xlabel("Дата", fontsize="small", color="midnightblue")
plt.ylabel("Температура", fontsize="small", color="midnightblue")
plt.title("Температура в м. Полтава", fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# Остаточно гарно офрмлений графік

# %%
date = pd.date_range(start='2021-09-01', freq='D', periods=8)
plt.plot(
    date,
    [23, 17, 17, 16, 15, 14, 17, 20],
    label='day temperature',
    linestyle='--',
    color='#FF5733',
    linewidth=2,
    marker='D',
)
plt.plot(
    date,
    [19, 11, 16, 11, 10, 10, 11, 16],
    label='night temperature',
    linestyle=':',
    color='#061358',
    linewidth=2,
    marker='^'
)
plt.ylim(0, 25)
plt.xlabel('Дата', fontsize='small', color='midnightblue')
plt.ylabel('Температура', fontsize='small', color='midnightblue')
plt.title('Температура у м.Полтава', fontsize=15)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Стовпчикові діаграми

# %%
plt.bar(
    ["США", "Китай", "Японія", "Велика Британія"],
    [39, 38, 27, 22],
    color=["b", "r", "y", "g"],
)

plt.xlabel("Країна", fontsize="small", color="midnightblue")
plt.ylabel("Кількість", fontsize="small", color="midnightblue")
plt.title("Золоті медалі: Літня олімпіада Токіо 2020", fontsize=15)
plt.show()

# %% [markdown]
# Кругові діаграми

# %%
labels = [
    "Junior Softwere Engineer",
    "Senior SoftwereEngineer",
    "Softwere Engineer",
    "System Architect",
    "Technical Lead",
]

data = [63, 31, 100, 2, 11]
explode=[0.15, 0, 0, 0, 0]
plt.pie(
    data,
    labels=labels,
    shadow= True,
    explode=explode,
    autopct="%.2f%%",
    pctdistance=1.15,
    labeldistance=1.35
)

plt.show()

# %% [markdown]
# Діаграми в полярних координатах

# %%
theta = np.linspace(0, 2.0 * np.pi, 1000)

r = np.sin(6 * theta)
plt.polar(theta, r)
plt.show()

# %% [markdown]
# Тривимірні графіки

# %% [markdown]
# Лінійний графік

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

theta_max = 8 * np.pi
n = 1000
theta = np.linspace(0, theta_max, n)
x = theta
z = np.sin(theta)
y = np.cos(theta)
ax.plot(x, y, z, "g")

plt.show()

# %% [markdown]
# Діаграма розсіювання

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

x = [5, 10, 15, 20]
z = [10, 0, 5, 15]
y = [0, 10, 5, 25]
s = [150, 130, 30, 160]
ax.scatter(x, y, x, s=s)

plt.show()

# %% [markdown]
# Каркасна поверхня

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

grid = np.arange(-10, 10, 0.5)
x, y = np.meshgrid(grid, grid)
z = x ** 2 * y ** 2 + 2

ax.plot_wireframe(x, y, z)

plt.show()

# %% [markdown]
# Поверхня

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

grid = np.arange(-10, 10, 0.5)
x, y = np.meshgrid(grid, grid)
z = x ** 2 * y ** 2 + 2

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# SEABORN

# %% [markdown]
# Функція lineplot

# %%
date = pd.date_range(start="2021-09-01", freq="D", periods=8)
day = [23, 17, 17, 16, 15, 14, 17, 20]
night = [19, 11, 16, 11, 10, 10, 11, 16]
df = pd.DataFrame({'date':date, 'day_temperature': day, 'night_temperature': night})
sns.lineplot(x="night_temperature", y="day_temperature", data=df)
# Out:
# <Axes: xlabel='night_temperature', ylabel='day_temperature'>
