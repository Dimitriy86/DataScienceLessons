# %%
import numpy as np
import pandas as pd

from sklearn import svm

# %% [markdown]
# ## Support Vector Machine

# %%
X = [[0, 0], [1, 1]]
y = [0, 1]

clf = svm.SVC()
clf.fit(X, y)

print(clf.predict([[2., 2.]]))
# Out:
# [1]

# %% [markdown]
# ## Дерева рішень
